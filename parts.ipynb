# %%
! pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\acer\anaconda3\envs\csit_workshop_venv\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\acer\anaconda3\envs\csit_workshop_venv\lib\site-packages (4.13.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\anaconda3\envs\csit_workshop_venv\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\anaconda3\envs\csit_workshop_venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\anaconda3\envs\csit_workshop_venv\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\envs\csit_workshop_venv\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: soupsieve>1.2 in c:\users\acer\anaconda3\envs\csit_workshop_venv\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\acer\anaconda3\envs\csit_workshop_venv\lib\site-packages (from beautifulsoup4) (4.12.2)

# %%
import os
import time
import json
import requests
from pathlib import Path
from duckduckgo_search import DDGS
from PIL import Image
from bs4 import BeautifulSoup

# Categories of computer parts with specific Newegg category URLs
computer_parts = {
    "CPU": "https://www.newegg.com/p/pl?d=CPU",
    "GPU": "https://www.newegg.com/p/pl?d=Graphics+Card",
    "Motherboard": "https://www.newegg.com/p/pl?d=Motherboard",
    "RAM": "https://www.newegg.com/p/pl?d=Memory",
    "SSD": "https://www.newegg.com/p/pl?d=Solid+State+Drive",
    "HDD": "https://www.newegg.com/p/pl?d=Hard+Drive",
    "Cooling System": "https://www.newegg.com/p/pl?d=Cooling+Fan",
    "Case": "https://www.newegg.com/p/pl?d=PC+Case"
}

# Base directory for storing images and JSON data
base_path = Path("computer-parts")
base_path.mkdir(exist_ok=True)

def download_images(dest, query, max_results=20):
    """Searches and downloads images from DuckDuckGo."""
    dest.mkdir(exist_ok=True, parents=True)
    with DDGS() as ddgs:
        results = list(ddgs.images(query, max_results=max_results))

    image_paths = []
    for i, result in enumerate(results):
        img_url = result.get("image", "")
        if not img_url:
            continue
        try:
            img_data = requests.get(img_url, timeout=10).content
            img_path = dest / f"{i}.jpg"
            with open(img_path, "wb") as f:
                f.write(img_data)
            print(f"Downloaded: {img_url}")
            image_paths.append(str(img_path))
        except Exception as e:
            print(f"Failed to download {img_url}: {e}")
    return image_paths

def resize_images(folder, max_size=400):
    """Resizes images in a folder to max_size pixels."""
    for img_file in folder.glob("*.jpg"):
        try:
            img = Image.open(img_file)
            img.thumbnail((max_size, max_size))
            img.save(img_file)
            print(f"Resized: {img_file}")
        except Exception as e:
            print(f"Failed to resize {img_file}: {e}")

def scrape_computer_parts():
    """Scrapes computer parts data from Newegg."""
    headers = {"User-Agent": "Mozilla/5.0"}
    
    parts_data = {}
    for part, search_url in computer_parts.items():
        print(f"Scraping data for {part}...")
        try:
            response = requests.get(search_url, headers=headers, timeout=10)
            soup = BeautifulSoup(response.text, "html.parser")
            items = soup.select("div.item-cell")[:20]  # Newegg uses 'div.item-cell' for product listings
            
            parts_data[part] = []
            for item in items:
                try:
                    brand_tag = item.select_one(".item-brand img")
                    brand = brand_tag["title"] if brand_tag else "Unknown"
                    
                    model_tag = item.select_one(".item-title")
                    model = model_tag.text.strip() if model_tag else "Unknown"
                    
                    price_tag = item.select_one(".price-current")
                    price = price_tag.text.strip() if price_tag else "Unknown"
                    
                    description = f"{model} from {brand} is a high-quality component built for optimal performance, efficiency, and durability. Ideal for gaming, professional workstations, and high-performance setups."
                    
                    specifications = []
                    spec_list = item.select("ul.item-features li")  # Newegg uses 'ul.item-features'
                    for spec in spec_list:
                        specifications.append(spec.text.strip())
                    
                    image_tag = item.select_one(".item-img img")
                    image_url = image_tag.get("src", "") if image_tag else ""
                    
                    parts_data[part].append({
                        "brand": brand,
                        "model": model,
                        "price": price,
                        "description": description,
                        "specifications": specifications if specifications else "Specifications not available.",
                        "image": image_url
                    })
                except Exception as e:
                    print(f"Error extracting data for {part}: {e}")
        except Exception as e:
            print(f"Failed to scrape {part}: {e}")
    
    return parts_data

# Scrape and save computer parts data
computer_parts_data = scrape_computer_parts()

# Loop through each computer part category
for part in computer_parts:
    part_path = base_path / part
    image_paths = download_images(part_path, query=f"{part} Computer Part", max_results=20)
    resize_images(part_path, max_size=400)
    
    # Assign images to data
    if part in computer_parts_data:
        for i, item in enumerate(computer_parts_data[part]):
            if i < len(image_paths):
                item["image"] = image_paths[i]
    
    time.sleep(3)

# Save updated data with images
json_path = base_path / "computer_parts.json"
with open(json_path, "w") as f:
    json.dump(computer_parts_data, f, indent=4)
print(f"Saved scraped parts data to {json_path}")

print("All images downloaded, resized, and data scraped!")
# Out:
# Scraping data for CPU...
# Scraping data for GPU...
# Scraping data for Motherboard...
# Scraping data for RAM...
# Scraping data for SSD...
# Scraping data for HDD...
# Scraping data for Cooling System...
# Scraping data for Case...
# Downloaded: https://www.techspot.com/articles-info/2000/images/2020-04-06-image-9.jpg
# Downloaded: https://thumbs.dreamstime.com/z/detail-central-processor-unit-below-cpu-computer-part-69118567.jpg
# Downloaded: https://i.insider.com/60402d8eb46d720018b04c1f?width=1200&format=jpeg
# Downloaded: https://i.ytimg.com/vi/YRKYW98r5eo/maxresdefault.jpg
# Downloaded: https://i1.wp.com/equilibriumest.com/wp-content/uploads/2017/07/beginners-guide-to-computer-hardware-computer-inside.jpg?ssl=1
# Downloaded: http://finalproject9c.weebly.com/uploads/5/0/7/1/50711767/244027473.png
# Downloaded: https://thumbs.dreamstime.com/z/internal-parts-pc-system-unit-background-look-inside-central-processing-computer-119635644.jpg
# Downloaded: https://d1rwhvwstyk9gu.cloudfront.net/2019/11/CPU.jpg
# Downloaded: https://i.ytimg.com/vi/BL-Alh1W82U/maxresdefault.jpg
# Downloaded: https://www.smtsa.net/wp-content/uploads/2020/02/Computer-Components-Inside-the-CPU.jpg
# Downloaded: https://techterms.com/img/lg/cpu_27.jpg
# Downloaded: https://www.scienceabc.com/wp-content/uploads/ext-www.scienceabc.com/wp-content/uploads/2016/01/processor-cpu.jpg-.jpg
# Downloaded: https://1.bp.blogspot.com/-SrdVklw0Uko/VgYF_uhX1uI/AAAAAAAAByA/euG-paxOKxA/s640/Basic+computer+parts.jpg
# Downloaded: https://www.trustedreviews.com/wp-content/uploads/sites/54/2021/03/Intel-Rocker-Lake-2-e1615908186584.jpg
# Downloaded: https://i.pinimg.com/originals/a3/04/0f/a3040f6dc880ce6af07cfdb4ff247a45.jpg
# Downloaded: https://www.shutterstock.com/shutterstock/photos/2220216813/display_1500/stock-vector-parts-of-computer-and-pc-hardware-components-in-outline-collection-set-labeled-elements-for-device-2220216813.jpg
# Downloaded: https://www.scienceabc.com/wp-content/uploads/2016/01/Computer-cabinet.png
# Downloaded: https://1.bp.blogspot.com/-LNWRUwU5H40/XvAnvXF8AcI/AAAAAAAABfU/YSFFYrPtgug09EPUVZlEhL8yMv3-34i8wCK4BGAsYHg/s1296/cpu.jpg
# Downloaded: https://2.bp.blogspot.com/-9rVPntSBZvU/WUe6kBI_fCI/AAAAAAAAADU/aVnnbA_BCGYlcSnZpda9izkebhgcYWM7ACLcBGAs/s1600/pc-684125_1920.jpg
# Downloaded: https://shahrecomputer.com/wp-content/uploads/cpu-what-is-2048x1580.png
# Resized: computer-parts\CPU\0.jpg
# Resized: computer-parts\CPU\1.jpg
# Resized: computer-parts\CPU\10.jpg
# Resized: computer-parts\CPU\11.jpg
# Resized: computer-parts\CPU\12.jpg
# Resized: computer-parts\CPU\13.jpg
# Resized: computer-parts\CPU\14.jpg
# Resized: computer-parts\CPU\15.jpg
# Resized: computer-parts\CPU\16.jpg
# Resized: computer-parts\CPU\17.jpg
# Resized: computer-parts\CPU\18.jpg
# Failed to resize computer-parts\CPU\19.jpg: cannot write mode RGBA as JPEG
# Resized: computer-parts\CPU\2.jpg
# Resized: computer-parts\CPU\3.jpg
# Resized: computer-parts\CPU\4.jpg
# Failed to resize computer-parts\CPU\5.jpg: cannot write mode RGBA as JPEG
# Resized: computer-parts\CPU\6.jpg
# Resized: computer-parts\CPU\7.jpg
# Resized: computer-parts\CPU\8.jpg
# Resized: computer-parts\CPU\9.jpg
# Downloaded: https://www.techspot.com/articles-info/1988/images/2020-03-16-image-3.jpg
# Downloaded: https://basigue.com/wp-content/uploads/2023/01/What-is-a-gpu-parts-of-a-graphics-card-1024x576.jpg
# Downloaded: https://buildpremiumpc.com/wp-content/uploads/2021/04/Graphics-Card-GPU-768x562.png
# Downloaded: https://www.hellotech.com/blog/wp-content/uploads/2020/02/what-is-a-gpu-770x462.jpg
# Downloaded: https://blog.paperspace.com/content/images/size/w1600/2022/06/gpu_anatomy.png
# Downloaded: https://www.overclockers.co.uk/blog/wp-content/uploads/2022/12/221212-Anatomy-of-a-GPU-Feature-Image-Graphic.jpg
# Downloaded: https://www.ibik.ru/images/articels/blok/371/nvidia.jpg
# Downloaded: https://static1.makeuseofimages.com/wordpress/wp-content/uploads/2021/07/New-GPU-featured.jpg
# Downloaded: https://external-preview.redd.it/GO2Bsd9M1WaSuL5GSruP6SgG1TA3ZR6EkiS17pQlteM.png?width=960&crop=smart&auto=webp&s=336a93af1bc94570d969f58fbd11539cd2e0dd06
# Downloaded: https://www.techspot.com/articles-info/1988/images/2020-02-23-image-13.jpg
# Downloaded: https://2.bp.blogspot.com/-PzDSCY3G1Ss/XOWDGGuSWeI/AAAAAAAAAJY/6StGLuUnbkUcxU8nSjupG7irLEwEJmkcwCLcBGAs/s1600/images+%284%29.jpeg
# Downloaded: https://images.techhive.com/images/article/2015/04/gpu-install-5-of-7-100580851-orig.jpg
# Downloaded: https://www.vssmonitoring.com/wp-content/uploads/2022/01/ROG_3080_10-1.jpg
# Downloaded: https://www.techspot.com/articles-info/1988/images/2020-03-16-image.jpg
# Downloaded: https://www.gamespot.com/a/uploads/original/917/9176928/2586096-8053135112-24399.jpg
# Downloaded: https://www.techspot.com/articles-info/1988/images/2020-03-15-image.png
# Downloaded: https://www.techspot.com/articles-info/1988/images/2020-02-23-image-29.jpg
# Downloaded: https://voltcave.com/wp-content/uploads/2022/02/gpu.jpg
# Downloaded: https://www.akcustomcomputers.com/wp-content/uploads/2021/01/gpu-e1609645103740.jpg
# Downloaded: https://challenges.robotevents.com/uploads/0004189_original.jpg
# Resized: computer-parts\GPU\0.jpg
# Failed to resize computer-parts\GPU\1.jpg: cannot identify image file 'computer-parts\\GPU\\1.jpg'
# Resized: computer-parts\GPU\10.jpg
# Resized: computer-parts\GPU\11.jpg
# Resized: computer-parts\GPU\12.jpg
# Resized: computer-parts\GPU\13.jpg
# Resized: computer-parts\GPU\14.jpg
# Failed to resize computer-parts\GPU\15.jpg: cannot write mode P as JPEG
# Resized: computer-parts\GPU\16.jpg
# Failed to resize computer-parts\GPU\17.jpg: cannot identify image file 'computer-parts\\GPU\\17.jpg'
# Failed to resize computer-parts\GPU\18.jpg: cannot identify image file 'computer-parts\\GPU\\18.jpg'
# Resized: computer-parts\GPU\19.jpg
# Failed to resize computer-parts\GPU\2.jpg: cannot write mode RGBA as JPEG
# Failed to resize computer-parts\GPU\3.jpg: cannot identify image file 'computer-parts\\GPU\\3.jpg'
# Failed to resize computer-parts\GPU\4.jpg: cannot write mode RGBA as JPEG
# Resized: computer-parts\GPU\5.jpg
# Resized: computer-parts\GPU\6.jpg
# Resized: computer-parts\GPU\7.jpg
# Failed to resize computer-parts\GPU\8.jpg: cannot write mode P as JPEG
# Resized: computer-parts\GPU\9.jpg
# Downloaded: https://i1.wp.com/artofpc.com/wp-content/uploads/2021/08/Motherboard-Diagram.jpg?fit=1024,852&ssl=1
# Downloaded: https://xpertlab.com/wp-content/uploads/2020/03/Intel_D945GCCR_Socket_775-1024x768.png
# Downloaded: https://cdn.britannica.com/64/170564-050-7A0A86A2/motherboard-for-computer.jpg
# Downloaded: https://4.bp.blogspot.com/-ThuHzKPPWjk/VjwxBghDq2I/AAAAAAAAC_s/TcLZtlRlcV4/s1600/Computer+Motherboard+Parts.jpg
# Downloaded: https://www.scientecheasy.com/wp-content/uploads/2023/07/components-of-motherboard-300x240.png
# Downloaded: https://www.partitionwizard.com/images/uploads/articles/2020/07/motherboard-components/motherboard-components-7.jpg
# Downloaded: https://www.tech21century.com/wp-content/uploads/2022/04/motherboardDepositphotos_2544377_XL.jpg
# Downloaded: https://miro.medium.com/v2/resize:fit:818/0*xC3hsaAv2P2ICE3_.png
# Downloaded: http://www.buildcomputers.net/images/motherboard-components.jpg
# Downloaded: https://www.chtips.com/wp-content/uploads/2021/04/ATX-Motherboard.png
# Downloaded: https://www.computer-hardware-explained.com/images/xmotherboard-labelled5.jpgic.Pf3YswVAez.jpg
# Downloaded: http://www.buildcomputers.net/images/motherboard-parts.jpg
# Downloaded: https://www.learncomputerscienceonline.com/wp-content/uploads/2020/05/Computer-Motherboard-768x474.jpg
# Downloaded: https://www.computerhope.com/cdn/bigmb.jpg
# Downloaded: https://pcgamehaven.com/wp-content/uploads/importart-parts-of-a-motherboard.jpg
# Downloaded: https://eduinput.com/wp-content/uploads/2022/08/imageof-componenets-of-motherboard.jpg
# Downloaded: https://cdn-images-1.medium.com/max/1600/1*gaNOskXGiXR51GooI58ZPg.png
# Downloaded: https://media.tech-latest.com/wp-content/uploads/2022/11/06132200/Motherboard-Components.jpg
# Downloaded: https://srcwap.com/wp-content/uploads/2020/07/How-to-Learn-the-Model-of-the-Motherboard-in-the.jpg
# Downloaded: https://pcguide101.com/wp-content/uploads/2022/01/motherboard-main-2-watermark.jpg
# Resized: computer-parts\Motherboard\0.jpg
# Failed to resize computer-parts\Motherboard\1.jpg: cannot identify image file 'computer-parts\\Motherboard\\1.jpg'
# Resized: computer-parts\Motherboard\10.jpg
# Resized: computer-parts\Motherboard\11.jpg
# Resized: computer-parts\Motherboard\12.jpg
# Resized: computer-parts\Motherboard\13.jpg
# Resized: computer-parts\Motherboard\14.jpg
# Resized: computer-parts\Motherboard\15.jpg
# Failed to resize computer-parts\Motherboard\16.jpg: cannot write mode RGBA as JPEG
# Resized: computer-parts\Motherboard\17.jpg
# Resized: computer-parts\Motherboard\18.jpg
# Resized: computer-parts\Motherboard\19.jpg
# Resized: computer-parts\Motherboard\2.jpg
# Resized: computer-parts\Motherboard\3.jpg
# Resized: computer-parts\Motherboard\4.jpg
# Resized: computer-parts\Motherboard\5.jpg
# Resized: computer-parts\Motherboard\6.jpg
# Failed to resize computer-parts\Motherboard\7.jpg: cannot write mode RGBA as JPEG
# Resized: computer-parts\Motherboard\8.jpg
# Failed to resize computer-parts\Motherboard\9.jpg: cannot write mode P as JPEG
# Downloaded: https://youngwonks.s3.amazonaws.com/Blogs/ram.png
# Downloaded: https://thumbs.dreamstime.com/z/computer-ram-system-main-memory-random-access-onboard-detail-close-up-high-resolution-installed-socket-motherboard-168743777.jpg
# Downloaded: https://d1rwhvwstyk9gu.cloudfront.net/2019/11/RAM.jpg
# Downloaded: https://cdn.stocksnap.io/img-thumbs/960w/O59DSLQQFF.jpg
# Downloaded: https://thumbs.dreamstime.com/z/close-up-ram-motherboard-parts-computer-pc-white-background-close-up-ram-motherboard-parts-computer-pc-123474726.jpg
# Downloaded: https://thumbs.dreamstime.com/z/computer-ram-system-memory-main-memory-random-access-memory-internal-memory-onboard-computer-detail-close-up-high-resolution-168835738.jpg
# Downloaded: https://img.freepik.com/free-photo/computer-memory-ram-circuit-motherboard_150455-2108.jpg?size=626&ext=jpg
# Downloaded: https://miro.medium.com/max/12000/0*U_3tUwUYIu5EgtWH
# Downloaded: https://www.clipartmax.com/png/middle/94-941968_system-memory-parts-of-computer-ram.png
# Downloaded: https://p1.pxfuel.com/preview/879/954/537/computer-ram-components-modules-parts-pc.jpg
# Downloaded: https://www.pugetsystems.com/pic_disp.php?id=32588
# Downloaded: https://www.distrelec.de/Web/WebShopImages/landscape_large/6-/01/Kingston_KCP3L16NS8_4_30061436-01.jpg
# Downloaded: http://cdn.thecoolist.com/wp-content/uploads/2017/04/RAM-computer-parts-960x720.jpg
# Downloaded: https://notebooks.com/wp-content/uploads/2013/10/shutterstock_133277192.jpg
# Downloaded: https://image.shutterstock.com/z/stock-photo-computer-ram-computer-parts-computer-memory-1115944895.jpg
# Downloaded: https://img.freepik.com/premium-photo/ddr-ram-computer-memory-modules-isolated-white_708636-691.jpg?w=2000
# Downloaded: https://i.ytimg.com/vi/GAE2CYuHMrw/maxresdefault.jpg
# Downloaded: https://static7.depositphotos.com/1242686/754/i/950/depositphotos_7541439-stock-photo-ram-parts-of-computer.jpg
# Downloaded: https://c8.alamy.com/comp/CFAT4R/computer-ram-memory-CFAT4R.jpg
# Downloaded: https://d29fhpw069ctt2.cloudfront.net/photo/54023/preview/ram-computer-part_preview_909d.jpg
# Resized: computer-parts\RAM\0.jpg
# Resized: computer-parts\RAM\1.jpg
# Resized: computer-parts\RAM\10.jpg
# Resized: computer-parts\RAM\11.jpg
# Resized: computer-parts\RAM\12.jpg
# Resized: computer-parts\RAM\13.jpg
# Resized: computer-parts\RAM\14.jpg
# Resized: computer-parts\RAM\15.jpg
# Resized: computer-parts\RAM\16.jpg
# Resized: computer-parts\RAM\17.jpg
# Resized: computer-parts\RAM\18.jpg
# Resized: computer-parts\RAM\19.jpg
# Resized: computer-parts\RAM\2.jpg
# Failed to resize computer-parts\RAM\3.jpg: cannot identify image file 'computer-parts\\RAM\\3.jpg'
# Resized: computer-parts\RAM\4.jpg
# Resized: computer-parts\RAM\5.jpg
# Resized: computer-parts\RAM\6.jpg
# Resized: computer-parts\RAM\7.jpg
# Resized: computer-parts\RAM\8.jpg
# Resized: computer-parts\RAM\9.jpg
# Downloaded: https://servicepclaptop.com/wp-content/uploads/2021/06/ssd-solid-state-drive.jpg
# Downloaded: https://res.cloudinary.com/lwgatsby/f_auto/www/uploads/2018/02/image2.jpg
# Downloaded: https://cdn.wccftech.com/wp-content/uploads/2013/01/SSD-525.jpg
# Downloaded: https://i0.wp.com/www.deskdecode.com/wp-content/uploads/2020/01/ssdvs_parts-min_zps6bkphhdt.jpg?resize=378,369&ssl=1
# Downloaded: https://www.minitool.com/images/uploads/lib/2019/06/ssd/ssd-3.jpg
# Downloaded: https://www.mycloudwiki.com/wp-content/uploads/2016/06/SSD-1024x683.jpg
# Downloaded: http://diskmfr.com/wp-content/uploads/2022/04/HDD-SSD-Inside.png
# Downloaded: https://i1.wp.com/www.thessdreview.com/wp-content/uploads/2011/12/PCBFront-31.jpg?fit=1024,683&ssl=1
# Downloaded: https://www.backblaze.com/blog/wp-content/uploads/2019/01/ssd.jpg
# Downloaded: http://www.thessdreview.com/wp-content/uploads/2011/12/PCBFront.jpg
# Downloaded: https://images.freeimages.com/images/premium/previews/4334/43345568-solid-state-drive-diagram.jpg
# Downloaded: https://ssd-guru.de/wp-content/uploads/2020/10/bigstock-SSD-state-solid-drives-disk-on-311822974-scaled.jpg
# Downloaded: https://2.bp.blogspot.com/-NbMfVQrcMFs/WACh_1KlzyI/AAAAAAAAAGg/ciRPjNNQNigiuD3AJe_rWuGm9ir6nD6kgCLcB/s1600/Crucial-M550-1TB-SSD-PCB-Front2.png
# Downloaded: https://www.datocms-assets.com/34299/1663155864-hard-disk-drive-hdd-solid-state-drive-ssd-and-ssd-2021-08-29-21-04-56-utc-1.jpg
# Downloaded: https://platinumdatarecovery.com/wp-content/uploads/2021/11/main-components.png
# Downloaded: https://www.cgdirector.com/wp-content/uploads/media/2022/01/How-does-an-SSD-Work-1-1024x540.jpg
# Downloaded: https://cdn.mos.cms.futurecdn.net/xj7PFra33kcXEj5XSsBf97-1200-80.jpg
# Downloaded: https://i0.wp.com/www.neweggbusiness.com/smartbuyer/wp-content/uploads/iStock-1001703646.jpg?fit=1256,835
# Downloaded: https://i2.wp.com/www.neweggbusiness.com/smartbuyer/wp-content/uploads/hard-disk-ssd-m2-on-the-motherboard-background-picture-id1060606376.jpg?ssl=1
# Downloaded: https://i0.wp.com/www.alphr.com/wp-content/uploads/2016/01/motherboard-connections_0.jpg?resize=1200,675&ssl=1
# Failed to resize computer-parts\SSD\0.jpg: cannot identify image file 'computer-parts\\SSD\\0.jpg'
# Resized: computer-parts\SSD\1.jpg
# Resized: computer-parts\SSD\10.jpg
# Resized: computer-parts\SSD\11.jpg
# Failed to resize computer-parts\SSD\12.jpg: cannot write mode RGBA as JPEG
# Resized: computer-parts\SSD\13.jpg
# Resized: computer-parts\SSD\14.jpg
# Resized: computer-parts\SSD\15.jpg
# Resized: computer-parts\SSD\16.jpg
# Resized: computer-parts\SSD\17.jpg
# Resized: computer-parts\SSD\18.jpg
# Resized: computer-parts\SSD\19.jpg
# Resized: computer-parts\SSD\2.jpg
# Resized: computer-parts\SSD\3.jpg
# Resized: computer-parts\SSD\4.jpg
# Resized: computer-parts\SSD\5.jpg
# Failed to resize computer-parts\SSD\6.jpg: cannot write mode P as JPEG
# Resized: computer-parts\SSD\7.jpg
# Failed to resize computer-parts\SSD\8.jpg: cannot identify image file 'computer-parts\\SSD\\8.jpg'
# Resized: computer-parts\SSD\9.jpg
# Downloaded: https://www.red-gate.com/simple-talk/wp-content/uploads/2020/02/word-image-6.png
# Downloaded: http://c8.alamy.com/comp/BB49BG/cross-section-of-a-computer-hard-drive-BB49BG.jpg
# Downloaded: https://eduinput.com/wp-content/uploads/2022/09/image-of-components-of-HDD-2.jpg
# Downloaded: https://images.techhive.com/images/article/2014/08/upside-down-hard-drive-showing-screw-holes-100367392-orig.jpg
# Downloaded: https://c8.alamy.com/comp/G3ERCF/computer-sata-hard-disk-drive-inside-internals-G3ERCF.jpg
# Downloaded: https://i.ytimg.com/vi/2et9h-Ggm3A/maxresdefault.jpg
# Downloaded: https://www.red-gate.com/simple-talk/wp-content/uploads/2020/02/word-image-12.jpeg
# Downloaded: https://thumbs.dreamstime.com/z/computer-s-hard-disk-hdd-data-storage-drive-shield-isolated-white-background-show-magnetic-disc-electronic-part-178418667.jpg
# Downloaded: https://thumbs.dreamstime.com/b/computer-hard-disk-parts-some-39917337.jpg
# Downloaded: https://hddscan.com/doc/images/hdd_main_parts/main.jpg
# Downloaded: https://thumbs.dreamstime.com/z/computer-s-hard-disk-hdd-data-storage-drive-shield-isolated-white-background-show-magnetic-disc-electronic-part-178418610.jpg
# Downloaded: https://thumbs.dreamstime.com/b/computer-s-hard-disk-hdd-data-storage-drive-shield-isolated-white-background-show-magnetic-disc-electronic-part-178418553.jpg
# Downloaded: https://purepng.com/public/uploads/large/purepng.com-internal-hard-disk-driveelectronics-hard-disk-hard-drive-941524662468kfynn.png
# Downloaded: https://www.lifewire.com/thmb/I54BplmwjrEgWJGfaBu3pXflcDg=/2200x1467/filters:fill(auto,1)/what-is-a-hard-disk-drive-2618152-6baa983ee974468383c6b392d4e4375d.png
# Downloaded: https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6331/6331502_sa.jpg
# Downloaded: https://c8.alamy.com/comp/BWP3R9/hdd-computer-part-done-in-3d-isolated-BWP3R9.jpg
# Downloaded: https://www.profesionalreview.com/wp-content/uploads/2018/05/partes-de-un-disco-duro.jpg
# Downloaded: https://5.imimg.com/data5/SELLER/Default/2021/1/TS/JP/OW/7808107/computer-data-storage-hard-disk.jpg
# Downloaded: https://get.pxhere.com/photo/technology-drive-desktop-product-hard-hard-disk-drive-electronic-device-computer-hardware-computer-component-data-storage-device-1387077.jpg
# Downloaded: https://images.wondershare.com/recoverit/article/2019/08/overview-laptop-drive.jpg
# Failed to resize computer-parts\HDD\0.jpg: cannot write mode P as JPEG
# Resized: computer-parts\HDD\1.jpg
# Resized: computer-parts\HDD\10.jpg
# Resized: computer-parts\HDD\11.jpg
# Failed to resize computer-parts\HDD\12.jpg: cannot write mode RGBA as JPEG
# Failed to resize computer-parts\HDD\13.jpg: cannot write mode P as JPEG
# Failed to resize computer-parts\HDD\14.jpg: cannot identify image file 'computer-parts\\HDD\\14.jpg'
# Resized: computer-parts\HDD\15.jpg
# Resized: computer-parts\HDD\16.jpg
# Resized: computer-parts\HDD\17.jpg
# Resized: computer-parts\HDD\18.jpg
# Resized: computer-parts\HDD\19.jpg
# Resized: computer-parts\HDD\2.jpg
# Resized: computer-parts\HDD\3.jpg
# Resized: computer-parts\HDD\4.jpg
# Resized: computer-parts\HDD\5.jpg
# Resized: computer-parts\HDD\6.jpg
# Resized: computer-parts\HDD\7.jpg
# Resized: computer-parts\HDD\8.jpg
# Resized: computer-parts\HDD\9.jpg
# Downloaded: https://www.falconcomputers.co.uk/media/product/76552/coolermaster-cooler-master-masterair-ma410p-cpu-cooling-system.jpg.jpg
# Downloaded: https://cdn.mos.cms.futurecdn.net/6w3YwzqyK4XK39HgQfwXdN.jpg
# Downloaded: https://cdn.mos.cms.futurecdn.net/9fdc0e6c7e4e1e175a8b986dc221e1cb-970-80.png
# Downloaded: https://img.favpng.com/19/9/17/computer-system-cooling-parts-water-cooling-antec-central-processing-unit-cooler-master-png-favpng-asShmWsxf2C5GrXCLJgWkTRKm.jpg
# Downloaded: https://thumbs.dreamstime.com/z/part-cooling-laptop-computer-radiator-cooling-system-computer-part-laptop-repair-closeup-part-cooling-laptop-266542680.jpg
# Downloaded: https://miro.medium.com/max/1322/0*TvXTjxkGhwUDObzh.png
# Downloaded: https://www.researchgate.net/profile/Sukhvinder-Kang/publication/267621341/figure/fig1/AS:535234624327680@1504621286273/Liquid-Cooling-System-for-a-PC.png
# Downloaded: https://miro.medium.com/max/1276/1*wuHdk6BoRA8jYd3n54lUww.png
# Downloaded: https://thumbs.dreamstime.com/b/open-disassembled-computer-system-unit-cooling-fans-installation-parts-table-274492820.jpg
# Downloaded: https://thumbs.dreamstime.com/z/cooling-system-processor-computer-cooler-fan-installed-computer-motherboard-electronic-computer-168990246.jpg
# Downloaded: https://www.build-gaming-computers.com/images/build-water-cooling-pc-guide.jpg
# Downloaded: https://www.shutterstock.com/shutterstock/photos/2067662429/display_1500/stock-photo-liquid-cooling-system-of-computer-components-processor-video-card-heat-dissipation-high-2067662429.jpg
# Downloaded: https://image.made-in-china.com/2f0j00lkHcBOvClLqP/Intel-AMD-CPU-Heatsink-Aluminum-Alloy-Cooling-System-Computer-Part.jpg
# Downloaded: https://i.ytimg.com/vi/W7Ii7IojUTA/maxresdefault.jpg
# Downloaded: https://www.thetechwire.com/wp-content/uploads/2021/12/Heatsink-and-fan-of-central-processing-or-the-CPU-cooler-inside-pc-system-unit.jpg
# Downloaded: https://images-na.ssl-images-amazon.com/images/I/61KyiAJ-S2L._SL1444_.jpg
# Downloaded: https://static0.makeuseofimages.com/wordpress/wp-content/uploads/2021/02/Cooler-Master-Hyper-212-heatsink.jpg
# Downloaded: https://miro.medium.com/max/552/1*eif79cpaZQwnfHKrgDm1Tw.png
# Downloaded: https://thumbs.dreamstime.com/z/computer-parts-cooling-ventilation-system-136795762.jpg
# Downloaded: https://images.idgesg.net/images/article/2021/08/case-fan-airflow-2-100898303-orig.jpg?auto=webp
# Resized: computer-parts\Cooling System\0.jpg
# Resized: computer-parts\Cooling System\1.jpg
# Resized: computer-parts\Cooling System\10.jpg
# Resized: computer-parts\Cooling System\11.jpg
# Resized: computer-parts\Cooling System\12.jpg
# Resized: computer-parts\Cooling System\13.jpg
# Resized: computer-parts\Cooling System\14.jpg
# Resized: computer-parts\Cooling System\15.jpg
# Resized: computer-parts\Cooling System\16.jpg
# Failed to resize computer-parts\Cooling System\17.jpg: cannot write mode RGBA as JPEG
# Resized: computer-parts\Cooling System\18.jpg
# Resized: computer-parts\Cooling System\19.jpg
# Resized: computer-parts\Cooling System\2.jpg
# Resized: computer-parts\Cooling System\3.jpg
# Resized: computer-parts\Cooling System\4.jpg
# Failed to resize computer-parts\Cooling System\5.jpg: cannot write mode RGBA as JPEG
# Failed to resize computer-parts\Cooling System\6.jpg: cannot identify image file 'computer-parts\\Cooling System\\6.jpg'
# Failed to resize computer-parts\Cooling System\7.jpg: cannot write mode RGBA as JPEG
# Resized: computer-parts\Cooling System\8.jpg
# Resized: computer-parts\Cooling System\9.jpg
# Downloaded: https://cdn.mos.cms.futurecdn.net/rYBsVmPQbi3jQdf95TY2ce-1200-80.jpg
# Downloaded: http://2.bp.blogspot.com/_Svwa4PMZAQc/TS3N_alAmUI/AAAAAAAAAUE/jtoKw6ENUzA/s1600/computer+case1.JPG
# Downloaded: https://www.computer-hardware-explained.com/images/empty-computer-case-labeled2.jpg
# Downloaded: https://gamingrig.com/wp-content/uploads/pc-cases-ftrd-2-768x518.png
# Downloaded: http://images10.newegg.com/NeweggImage/productimage/11-147-237-01.jpg
# Downloaded: https://alexnld.com/wp-content/uploads/2020/01/f4e7adab-a35c-4026-8beb-6e06342bace9.png
# Downloaded: https://voltcave.com/wp-content/uploads/2020/04/robeytech-senna-featured-image.jpg
# Downloaded: https://tech4gamers.com/wp-content/uploads/2022/12/Lian-Li-PC-O11-Dynamic.jpg
# Downloaded: https://www.pcworld.com/wp-content/uploads/2021/09/dsc04685_final-100802535-orig.jpg?quality=50&strip=all&w=1024
# Downloaded: https://cdn.mos.cms.futurecdn.net/4ZCLnBGMBuuXUqHs2abyQM.jpg
# Downloaded: https://www.windowscentral.com/sites/wpcentral.com/files/styles/large/public/field/image/2021/04/lian-li-o11-dynamic-mini-case-build-side.jpg
# Downloaded: https://m.media-amazon.com/images/I/81nvxIhrYKL._AC_SL1500_.jpg
# Downloaded: http://s3.amazonaws.com/digitaltrends-uploads-prod/2016/01/PC-case.jpg
# Downloaded: https://www.quietpc.com/images/products/gel-dark-force-side@2x.jpg
# Downloaded: http://s3.amazonaws.com/digitaltrends-uploads-prod/2016/03/PC-Buildout-2016-guide.jpg
# Downloaded: https://i.etsystatic.com/25428148/r/il/4dca5e/2911313853/il_fullxfull.2911313853_a61r.jpg
# Downloaded: https://graphicscardhub.com/wp-content/uploads/2018/03/In-Win-D-Frame-2.0-Open-Air-Chassis.jpg
# Downloaded: https://i5.walmartimages.com/asr/74cf5057-3a0d-4dac-a51b-13e8141e9e58_1.fec56fb6d2452a894fea9c640c50d27d.jpeg
# Downloaded: https://www.falconcomputers.co.uk/media/product/86618/0/0/nzxt-h510-elite---premium-mid-tower-atx-case-pc-gaming-case---white-edition.jpg.jpg
# Downloaded: https://voltcave.com/wp-content/uploads/2020/04/mrjos94-1.jpg
# Resized: computer-parts\Case\0.jpg
# Resized: computer-parts\Case\1.jpg
# Resized: computer-parts\Case\10.jpg
# Resized: computer-parts\Case\11.jpg
# Resized: computer-parts\Case\12.jpg
# Resized: computer-parts\Case\13.jpg
# Resized: computer-parts\Case\14.jpg
# Resized: computer-parts\Case\15.jpg
# Resized: computer-parts\Case\16.jpg
# Resized: computer-parts\Case\17.jpg
# Resized: computer-parts\Case\18.jpg
# Failed to resize computer-parts\Case\19.jpg: cannot identify image file 'computer-parts\\Case\\19.jpg'
# Resized: computer-parts\Case\2.jpg
# Resized: computer-parts\Case\3.jpg
# Resized: computer-parts\Case\4.jpg
# Resized: computer-parts\Case\5.jpg
# Failed to resize computer-parts\Case\6.jpg: cannot identify image file 'computer-parts\\Case\\6.jpg'
# Resized: computer-parts\Case\7.jpg
# Resized: computer-parts\Case\8.jpg
# Resized: computer-parts\Case\9.jpg
# Saved scraped parts data to computer-parts\computer_parts.json
# All images downloaded, resized, and data scraped!
